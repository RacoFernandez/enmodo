# %% [markdown]
# # Análisis Encuesta Origen-Destino -  Limpieza de Datos & Cálculo de Indicadores

# %% [markdown]
# ## Uruguay - Montevideo - 2009

# %% [markdown]
# #### Elaborado por Paula Vásquez-Henríquez, Ariel López, Genaro Cuadros, Exequiel Gaete, Alba Vásquez y Juan Correa

# %%
# !pip3 uninstall matplotlib -y
# Out:
# Found existing installation: matplotlib 3.2.2
# Uninstalling matplotlib-3.2.2:
#   Successfully uninstalled matplotlib-3.2.2

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:35
# 🔁 Restarting kernel...

# %%
# !git clone https://github.com/zorzalerrante/aves.git aves_git
# Out:
# Cloning into 'aves_git'...
# remote: Enumerating objects: 832, done.
# remote: Counting objects: 100% (463/463), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 832 (delta 200), reused 435 (delta 183), pack-reused 369
# Receiving objects: 100% (832/832), 165.53 MiB | 26.90 MiB/s, done.
# Resolving deltas: 100% (323/323), done.
# Checking out files: 100% (280/280), done.

# %%
# !mamba env update --name base --file aves_git/environment-colab.yml
# Out:
# pkgs/r/linux-64          [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 404 KB / ?? (1.31 MB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# pkgs/r/linux-64          [] (00m:00s) Finalizing...
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 241 KB / ?? (793.99 KB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 343 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 248 KB / ?? (818.51 KB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) 192 KB / ?? (634.10 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) 584 KB / ?? (1.05 MB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) 584 KB / ?? (1.05 MB/s)
# pkgs/r/noarch            [] (00m:00s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) 584 KB / ?? (1.05 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) Finalizing...
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) Done
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/main/noarch         [] (00m:00s) Done
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# pkgs/main/noarch         [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 746 KB / ?? (1.35 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 628 KB / ?? (1.13 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (334.50 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) 192 KB / ?? (263.39 KB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) Finalizing...
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# pkgs/r/noarch            [] (00m:00s) Done
# pkgs/r/noarch            [] (00m:00s) Done
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 839 KB / ?? (1.12 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (1.53 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 812 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (1.86 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.44 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (3.03 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.56 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (2.18 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.26 MB/s)
# conda-forge/noarch       [] (00m:01s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.28 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 4 MB / ?? (3.19 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 3 MB / ?? (2.34 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) 4 MB / ?? (2.39 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) Finalizing...
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# pkgs/main/linux-64       [] (00m:01s) Done
# pkgs/main/linux-64       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.58 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.65 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) Finalizing...
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.53 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.77 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.77 MB/s)
# conda-forge/linux-64     [] (00m:01s) 8 MB / ?? (3.88 MB/s)
# conda-forge/linux-64     [] (00m:01s) 8 MB / ?? (3.88 MB/s)
# conda-forge/linux-64     [] (00m:01s) 8 MB / ?? (3.97 MB/s)
# conda-forge/linux-64     [] (00m:02s) 8 MB / ?? (3.97 MB/s)
# conda-forge/linux-64     [] (00m:02s) 9 MB / ?? (3.82 MB/s)
# conda-forge/linux-64     [] (00m:02s) 9 MB / ?? (3.82 MB/s)
# conda-forge/linux-64     [] (00m:02s) 10 MB / ?? (4.10 MB/s)
# conda-forge/linux-64     [] (00m:02s) 10 MB / ?? (4.10 MB/s)
# conda-forge/linux-64     [] (00m:02s) 11 MB / ?? (4.13 MB/s)
# conda-forge/linux-64     [] (00m:02s) 11 MB / ?? (4.13 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.16 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.16 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.18 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.18 MB/s)
# conda-forge/linux-64     [] (00m:02s) 13 MB / ?? (4.21 MB/s)
# conda-forge/linux-64     [] (00m:02s) 13 MB / ?? (4.21 MB/s)
# conda-forge/linux-64     [] (00m:02s) 14 MB / ?? (4.20 MB/s)
# conda-forge/linux-64     [] (00m:03s) 14 MB / ?? (4.20 MB/s)
# conda-forge/linux-64     [] (00m:03s) 14 MB / ?? (4.23 MB/s)
# conda-forge/linux-64     [] (00m:03s) 14 MB / ?? (4.23 MB/s)
# conda-forge/linux-64     [] (00m:03s) 15 MB / ?? (4.25 MB/s)
# conda-forge/linux-64     [] (00m:03s) 15 MB / ?? (4.25 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.26 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.26 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.25 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.25 MB/s)
# conda-forge/linux-64     [] (00m:03s) 17 MB / ?? (4.25 MB/s)
# conda-forge/linux-64     [] (00m:03s) Finalizing...
# conda-forge/linux-64     [] (00m:04s) Done
# conda-forge/linux-64     [] (00m:04s) Done
# conda-forge/linux-64     [] (00m:04s) Done
#
#
# Looking for: ['configparser', 'graphviz', 'python=3.7', 'matplotlib', 'seaborn', 'pandas', 'geopandas', 'libpysal', 'mapclassify', 'statsmodels', 'networkx', 'spectra', 'descartes', 'scikit-learn', 'wordcloud', 'pip', 'graph-tool', 'cytoolz']
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - configparser
#    - graphviz
#    - python==3.7
#    - matplotlib
#    - seaborn
#    - pandas
#    - geopandas
#    - libpysal
#    - mapclassify
#    - statsmodels
#    - networkx
#    - spectra
#    - descartes
#    - scikit-learn
#    - wordcloud
#    - pip
#    - graph-tool
#    - cytoolz
#
#
#   Package                      Version  Build                Channel                    Size
# ──────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
#   alsa-lib                       1.2.3  h516909a_0           conda-forge/linux-64     560 KB
#   at-spi2-atk                   2.38.0  h0630a04_3           conda-forge/linux-64     332 KB
#   at-spi2-core                  2.40.3  h0630a04_0           conda-forge/linux-64     643 KB
#   atk-1.0                       2.36.0  h3371d22_4           conda-forge/linux-64     560 KB
#   attrs                         21.2.0  pyhd8ed1ab_0         conda-forge/noarch        44 KB
#   beautifulsoup4                4.10.0  pyha770c72_0         conda-forge/noarch        77 KB
#   boost                         1.74.0  py37h6dcda5c_3       conda-forge/linux-64     342 KB
#   boost-cpp                     1.74.0  h312852a_4           conda-forge/linux-64      16 MB
#   branca                         0.4.2  pyhd8ed1ab_0         conda-forge/noarch        26 KB
#   bs4                           4.10.0  hd8ed1ab_0           conda-forge/noarch         4 KB
#   cairo                         1.16.0  h6cf1ce9_1008        conda-forge/linux-64       1 MB
#   cairomm                       1.12.2  ha770c72_3           conda-forge/linux-64      11 KB
#   cairomm-1.0                   1.12.2  h56b4340_3           conda-forge/linux-64     690 KB
#   cfitsio                        3.470  hb418390_7           conda-forge/linux-64       1 MB
#   click                          8.0.3  py37h89c1867_0       conda-forge/linux-64     145 KB
#   click-plugins                  1.1.1  py_0                 conda-forge/noarch         9 KB
#   cligj                          0.7.2  pyhd8ed1ab_1         conda-forge/noarch        10 KB
#   colormath                      3.0.0  py_2                 conda-forge/noarch        34 KB
#   configparser                   5.0.2  pyhd8ed1ab_0         conda-forge/noarch        21 KB
#   curl                          7.79.1  h2574ce0_1           conda-forge/linux-64     153 KB
#   cycler                        0.11.0  pyhd8ed1ab_0         conda-forge/noarch        10 KB
#   cytoolz                       0.11.0  py37h5e8e339_3       conda-forge/linux-64     403 KB
#   dbus                         1.13.18  hb2f20db_0           pkgs/main/linux-64       504 KB
#   descartes                      1.1.0  py_4                 conda-forge/noarch         7 KB
#   epoxy                          1.5.9  h7f98852_0           conda-forge/linux-64       2 MB
#   expat                          2.4.1  h9c3ff4c_0           conda-forge/linux-64     182 KB
#   fiona                         1.8.20  py37hb7e2723_2       conda-forge/linux-64       1 MB
#   folium                        0.12.0  pyhd8ed1ab_1         conda-forge/noarch        64 KB
#   font-ttf-dejavu-sans-mono       2.37  hab24e00_0           conda-forge/noarch       388 KB
#   font-ttf-inconsolata           3.000  h77eed37_0           conda-forge/noarch        94 KB
#   font-ttf-source-code-pro       2.038  h77eed37_0           conda-forge/noarch       684 KB
#   font-ttf-ubuntu                 0.83  hab24e00_0           conda-forge/noarch         2 MB
#   fontconfig                    2.13.1  hba837de_1005        conda-forge/linux-64     357 KB
#   fonts-conda-ecosystem              1  0                    conda-forge/noarch         4 KB
#   fonts-conda-forge                  1  0                    conda-forge/noarch         4 KB
#   freetype                      2.11.0  h70c0345_0           pkgs/main/linux-64       618 KB
#   freexl                         1.0.6  h7f98852_0           conda-forge/linux-64      48 KB
#   fribidi                       1.0.10  h516909a_0           conda-forge/linux-64     113 KB
#   g-ir-build-tools              1.68.0  py37h8a2ff1e_2       conda-forge/linux-64     247 KB
#   g-ir-host-tools               1.68.0  hc194b35_2           conda-forge/linux-64     102 KB
#   gdal                           3.3.2  py37hd5a0ba4_4       conda-forge/linux-64       2 MB
#   gdk-pixbuf                    2.42.6  h04a7f16_0           conda-forge/linux-64     609 KB
#   geopandas                     0.10.2  pyhd8ed1ab_0         conda-forge/noarch         5 KB
#   geopandas-base                0.10.2  pyha770c72_0         conda-forge/noarch       990 KB
#   geos                           3.9.1  h9c3ff4c_2           conda-forge/linux-64       1 MB
#   geotiff                        1.7.0  hcfb7246_3           conda-forge/linux-64     298 KB
#   gettext                       0.21.0  hf68c758_0           pkgs/main/linux-64         3 MB
#   giflib                         5.2.1  h516909a_2           conda-forge/linux-64      80 KB
#   glib                          2.68.4  h9c3ff4c_0           conda-forge/linux-64     447 KB
#   glib-tools                    2.68.4  h9c3ff4c_0           conda-forge/linux-64      86 KB
#   gmp                            6.2.1  h58526e2_0           conda-forge/linux-64     806 KB
#   gobject-introspection         1.68.0  py37hb87790b_2       conda-forge/linux-64     909 KB
#   graph-tool                      2.43  py37h3c24745_0       conda-forge/linux-64      26 KB
#   graph-tool-base                 2.43  py37hb8ebace_0       conda-forge/linux-64      66 MB
#   graphite2                     1.3.14  h23475e2_0           pkgs/main/linux-64        99 KB
#   graphviz                      2.49.1  h85b4f2f_0           conda-forge/linux-64       4 MB
#   gst-plugins-base              1.18.5  hf529b03_0           conda-forge/linux-64       3 MB
#   gstreamer                     1.18.5  h76c114f_0           conda-forge/linux-64       2 MB
#   gtk2                         2.24.33  h539f30e_1           conda-forge/linux-64       7 MB
#   gtk3                         3.24.29  h8c9bf5d_3           conda-forge/linux-64      10 MB
#   gts                            0.7.6  h64030ff_2           conda-forge/linux-64     411 KB
#   harfbuzz                       3.0.0  h83ec7ef_1           conda-forge/linux-64       2 MB
#   hdf4                          4.2.15  h10796ff_3           conda-forge/linux-64     950 KB
#   hdf5                          1.12.1  nompi_h2750804_101   conda-forge/linux-64       4 MB
#   hicolor-icon-theme              0.17  ha770c72_2           conda-forge/linux-64      14 KB
#   importlib-metadata             4.8.1  py37h89c1867_0       conda-forge/linux-64      32 KB
#   jbig                             2.1  h7f98852_2003        conda-forge/linux-64      43 KB
#   jinja2                         3.0.2  pyhd8ed1ab_0         conda-forge/noarch        99 KB
#   joblib                         1.1.0  pyhd8ed1ab_0         conda-forge/noarch       210 KB
#   jpeg                              9d  h516909a_0           conda-forge/linux-64     266 KB
#   json-c                          0.15  h98cffda_0           conda-forge/linux-64     274 KB
#   kealib                        1.4.14  h87e4c3c_3           conda-forge/linux-64     186 KB
#   kiwisolver                     1.3.2  py37h2527ec5_0       conda-forge/linux-64      78 KB
#   lcms2                           2.12  hddcbb42_0           conda-forge/linux-64     443 KB
#   lerc                             3.0  h9c3ff4c_0           conda-forge/linux-64     216 KB
#   libblas                        3.9.0  12_linux64_openblas  conda-forge/linux-64      12 KB
#   libcblas                       3.9.0  12_linux64_openblas  conda-forge/linux-64      12 KB
#   libclang                      11.1.0  default_ha53f305_1   conda-forge/linux-64      19 MB
#   libcups                        2.3.3  hf5a7f15_0           conda-forge/linux-64       5 MB
#   libdap4                       3.20.6  hd7c4107_2           conda-forge/linux-64      11 MB
#   libdeflate                       1.8  h7f98852_0           conda-forge/linux-64      67 KB
#   libevent                      2.1.10  h9b69904_4           conda-forge/linux-64       1 MB
#   libgd                          2.3.3  h6ad9fb6_0           conda-forge/linux-64     279 KB
#   libgdal                        3.3.2  h9c9eb65_4           conda-forge/linux-64      13 MB
#   libgfortran-ng                11.2.0  h69a702a_11          conda-forge/linux-64      19 KB
#   libgfortran5                  11.2.0  h5c6108e_11          conda-forge/linux-64       2 MB
#   libgirepository               1.68.0  h7771c88_2           conda-forge/linux-64     305 KB
#   libglib                       2.68.4  h3e27bee_0           conda-forge/linux-64       3 MB
#   libkml                         1.3.0  h238a007_1014        conda-forge/linux-64     591 KB
#   liblapack                      3.9.0  12_linux64_openblas  conda-forge/linux-64      12 KB
#   libllvm11                     11.1.0  hf817b99_2           conda-forge/linux-64      29 MB
#   libnetcdf                      4.8.1  nompi_hb3fd0d9_101   conda-forge/linux-64       1 MB
#   libnsl                         2.0.0  h7f98852_0           conda-forge/linux-64      31 KB
#   libogg                         1.3.5  h27cfd23_1           pkgs/main/linux-64       199 KB
#   libopenblas                   0.3.18  pthreads_h8fe5266_0  conda-forge/linux-64      10 MB
#   libopus                        1.3.1  h7f98852_1           conda-forge/linux-64     255 KB
#   libpng                        1.6.37  hed695b0_2           conda-forge/linux-64     359 KB
#   libpq                           13.3  hd57d9b9_2           conda-forge/linux-64       3 MB
#   libpysal                       4.5.1  pyhd8ed1ab_0         conda-forge/noarch         2 MB
#   librsvg                       2.52.2  hc3c00ef_0           conda-forge/linux-64       5 MB
#   librttopo                      1.1.0  h1185371_6           conda-forge/linux-64     235 KB
#   libspatialindex                1.9.3  h9c3ff4c_4           conda-forge/linux-64       5 MB
#   libspatialite                  5.0.1  h8796b1e_9           conda-forge/linux-64       4 MB
#   libtiff                        4.3.0  h6f004c6_2           conda-forge/linux-64     614 KB
#   libtool                        2.4.6  h9c3ff4c_1008        conda-forge/linux-64     511 KB
#   libuuid                       2.32.1  h14c3975_1000        conda-forge/linux-64      26 KB
#   libvorbis                      1.3.7  he1b5a44_0           conda-forge/linux-64     287 KB
#   libwebp                        1.2.1  h3452ae3_0           conda-forge/linux-64      84 KB
#   libwebp-base                   1.2.1  h7f98852_0           conda-forge/linux-64     845 KB
#   libxcb                          1.14  h7b6447c_0           pkgs/main/linux-64       505 KB
#   libxkbcommon                   1.0.3  he3ba5ed_0           conda-forge/linux-64     581 KB
#   libzip                         1.8.0  h4de3113_1           conda-forge/linux-64     126 KB
#   libzlib                       1.2.11  h36c2ea0_1013        conda-forge/linux-64      59 KB
#   mapclassify                    2.4.3  pyhd8ed1ab_0         conda-forge/noarch        36 KB
#   markupsafe                     2.0.1  py37h5e8e339_0       conda-forge/linux-64      22 KB
#   matplotlib                     3.4.3  py37h89c1867_1       conda-forge/linux-64       7 KB
#   matplotlib-base                3.4.3  py37h1058ff1_1       conda-forge/linux-64       7 MB
#   munch                          2.5.0  py_0                 conda-forge/noarch        12 KB
#   mysql-common                  8.0.27  ha770c72_1           conda-forge/linux-64       2 MB
#   mysql-libs                    8.0.27  hfa10184_1           conda-forge/linux-64       2 MB
#   networkx                       2.6.3  pyhd8ed1ab_1         conda-forge/noarch         1 MB
#   nspr                            4.32  h9c3ff4c_0           conda-forge/linux-64     231 KB
#   nss                             3.71  hb5efdd6_0           conda-forge/linux-64       2 MB
#   numpy                         1.21.3  py37h31617e3_0       conda-forge/linux-64       6 MB
#   olefile                         0.46  pyh9f0ad1d_1         conda-forge/noarch        32 KB
#   openjpeg                       2.4.0  hb52868f_1           conda-forge/linux-64     444 KB
#   pandas                         1.3.4  py37he8f5f7f_0       conda-forge/linux-64      13 MB
#   pango                        1.48.10  h54213e6_2           conda-forge/linux-64     403 KB
#   patsy                          0.5.2  pyhd8ed1ab_0         conda-forge/noarch       188 KB
#   pcre                            8.45  h9c3ff4c_0           conda-forge/linux-64     253 KB
#   pillow                         8.4.0  py37h5aabda8_0       pkgs/main/linux-64       644 KB
#   pixman                        0.40.0  h36c2ea0_0           conda-forge/linux-64     627 KB
#   pkg-config                    0.29.2  h516909a_1008        conda-forge/linux-64     120 KB
#   poppler                      21.09.0  ha39eefc_3           conda-forge/linux-64      17 MB
#   poppler-data                  0.4.11  hd8ed1ab_0           conda-forge/noarch         4 MB
#   postgresql                      13.3  h2510834_2           conda-forge/linux-64       5 MB
#   proj                           8.1.1  h277dcde_2           conda-forge/linux-64       3 MB
#   pycairo                       1.20.1  py37hfff247e_0       conda-forge/linux-64      77 KB
#   pygobject                     3.40.1  py37he6fa580_1       conda-forge/linux-64     286 KB
#   pyparsing                      3.0.4  pyhd8ed1ab_0         conda-forge/noarch        78 KB
#   pyproj                         3.2.1  py37hd495510_2       conda-forge/linux-64     499 KB
#   pyqt                          5.12.3  py37h89c1867_7       conda-forge/linux-64      21 KB
#   pyqt-impl                     5.12.3  py37he336c9b_7       conda-forge/linux-64       6 MB
#   pyqt5-sip                    4.19.18  py37hcd2ae1e_7       conda-forge/linux-64     310 KB
#   pyqtchart                       5.12  py37he336c9b_7       conda-forge/linux-64     256 KB
#   pyqtwebengine                 5.12.1  py37he336c9b_7       conda-forge/linux-64     175 KB
#   python-dateutil                2.8.2  pyhd8ed1ab_0         conda-forge/noarch       240 KB
#   pytz                          2021.3  pyhd8ed1ab_0         conda-forge/noarch       242 KB
#   qt                            5.12.9  hda022c4_4           conda-forge/linux-64     100 MB
#   rtree                          0.9.7  py37h0b55af0_2       conda-forge/linux-64      45 KB
#   scikit-learn                   1.0.1  py37hf0f1638_1       conda-forge/linux-64       8 MB
#   scipy                          1.7.1  py37hf2a6cf1_0       conda-forge/linux-64      22 MB
#   seaborn                       0.11.2  hd8ed1ab_0           conda-forge/noarch         4 KB
#   seaborn-base                  0.11.2  pyhd8ed1ab_0         conda-forge/noarch       223 KB
#   shapely                        1.8.0  py37h48c49eb_0       conda-forge/linux-64     367 KB
#   sigcpp-2.0                    2.10.7  h9c3ff4c_0           conda-forge/linux-64     190 KB
#   soupsieve                      2.2.1  pyhd3eb1b0_0         pkgs/main/noarch          32 KB
#   sparsehash                     2.0.4  h9c3ff4c_0           conda-forge/linux-64      86 KB
#   spectra                       0.0.11  py_1                 conda-forge/noarch        19 KB
#   statsmodels                   0.13.0  py37hb1e94ed_0       conda-forge/linux-64      11 MB
#   threadpoolctl                  3.0.0  pyh8a188c0_0         conda-forge/noarch        17 KB
#   tiledb                         2.3.4  he87e0bf_0           conda-forge/linux-64       4 MB
#   toolz                         0.11.1  py_0                 conda-forge/noarch        46 KB
#   tornado                          6.1  py37h5e8e339_1       conda-forge/linux-64     646 KB
#   typing_extensions           3.10.0.2  pyha770c72_0         conda-forge/noarch        28 KB
#   tzcode                         2021e  h7f98852_0           conda-forge/linux-64      69 KB
#   tzdata                         2021e  he74cb21_0           conda-forge/noarch       121 KB
#   wordcloud                      1.8.1  py37h5e8e339_1       conda-forge/linux-64     189 KB
#   xerces-c                       3.2.3  h9d8b166_3           conda-forge/linux-64       2 MB
#   xorg-fixesproto                  5.0  h14c3975_1002        conda-forge/linux-64       8 KB
#   xorg-inputproto                2.3.2  h14c3975_1002        conda-forge/linux-64      18 KB
#   xorg-kbproto                   1.0.7  h14c3975_1002        conda-forge/linux-64      26 KB
#   xorg-libice                   1.0.10  h516909a_0           conda-forge/linux-64      57 KB
#   xorg-libsm                     1.2.3  hd9c2040_1000        conda-forge/linux-64      26 KB
#   xorg-libx11                    1.7.2  h7f98852_0           conda-forge/linux-64     941 KB
#   xorg-libxext                   1.3.4  h7f98852_1           conda-forge/linux-64      54 KB
#   xorg-libxfixes                 5.0.3  h7f98852_1004        conda-forge/linux-64      18 KB
#   xorg-libxi                    1.7.10  h7f98852_0           conda-forge/linux-64      46 KB
#   xorg-libxrender               0.9.10  h7f98852_1003        conda-forge/linux-64      32 KB
#   xorg-libxtst                   1.2.3  h7f98852_1002        conda-forge/linux-64      31 KB
#   xorg-recordproto              1.14.2  h516909a_1002        conda-forge/linux-64       7 KB
#   xorg-renderproto              0.11.1  h14c3975_1002        conda-forge/linux-64       8 KB
#   xorg-xextproto                 7.3.0  h14c3975_1002        conda-forge/linux-64      27 KB
#   xorg-xproto                   7.0.31  h14c3975_1007        conda-forge/linux-64      72 KB
#   xyzservices                2021.10.0  pyhd8ed1ab_0         conda-forge/noarch        28 KB
#   zipp                           3.6.0  pyhd8ed1ab_0         conda-forge/noarch        12 KB
#   zstandard                     0.16.0  py37h5e8e339_0       conda-forge/linux-64     724 KB
#
#   Change:
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
#   zlib                          1.2.11  h516909a_1010        installed
#   zlib                          1.2.11  h36c2ea0_1013        conda-forge/linux-64      86 KB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
#   krb5                          1.17.2  h926e7f8_0           installed
#   krb5                          1.19.2  hcc1bbae_2           conda-forge/linux-64       1 MB
#   libarchive                     3.5.1  h3f442fb_1           installed
#   libarchive                     3.5.2  hccf745f_1           conda-forge/linux-64       2 MB
#   libcurl                       7.75.0  hc4aaa36_0           installed
#   libcurl                       7.79.1  h2574ce0_1           conda-forge/linux-64     335 KB
#   libgcc-ng                      9.3.0  h2828fa1_18          installed
#   libgcc-ng                     11.2.0  h1d223b6_11          conda-forge/linux-64     887 KB
#   libgomp                        9.3.0  h2828fa1_18          installed
#   libgomp                       11.2.0  h1d223b6_11          conda-forge/linux-64     427 KB
#   libssh2                        1.9.0  ha56f1ee_6           installed
#   libssh2                       1.10.0  ha56f1ee_2           conda-forge/linux-64     233 KB
#   libstdcxx-ng                   9.3.0  h6de172a_18          installed
#   libstdcxx-ng                  11.2.0  he4da1e4_11          conda-forge/linux-64       4 MB
#   libxml2                       2.9.10  h72842e0_3           installed
#   libxml2                       2.9.12  h72842e0_0           conda-forge/linux-64     772 KB
#   openssl                       1.1.1j  h7f98852_0           installed
#   openssl                       1.1.1l  h7f98852_0           conda-forge/linux-64       2 MB
#   readline                         8.0  he28a2e2_2           installed
#   readline                         8.1  h46c0cb4_0           conda-forge/linux-64     295 KB
#   sqlite                        3.34.0  h74cdb3f_0           installed
#   sqlite                        3.36.0  h9cd32fc_2           conda-forge/linux-64       1 MB
#   tk                            8.6.10  h21135ba_1           installed
#   tk                            8.6.11  h27826a3_1           conda-forge/linux-64       3 MB
#   zstd                           1.4.9  ha95c52a_0           installed
#   zstd                           1.5.0  ha95c52a_0           conda-forge/linux-64     490 KB
#
#   Summary:
#
#   Install: 187 packages
#   Change: 1 packages
#   Upgrade: 13 packages
#
#   Total download: 501 MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
#
# Downloading and Extracting Packages
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00,  4.51it/s]
# geos-3.9.1           | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# libnetcdf-4.8.1      | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.78it/s]
# mysql-common-8.0.27  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.47it/s]
# krb5-1.19.2          | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.71it/s]
# pango-1.48.10        | 403 KB    | : 100% 1.0/1 [00:00<00:00,  6.14it/s]
# pytz-2021.3          | 242 KB    | : 100% 1.0/1 [00:00<00:00,  6.59it/s]
# tiledb-2.3.4         | 4.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
# libuuid-2.32.1       | 26 KB     | : 100% 1.0/1 [00:00<00:00, 19.68it/s]
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:00<00:00, 10.04it/s]
# xerces-c-3.2.3       | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
# fiona-1.8.20         | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# libstdcxx-ng-11.2.0  | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.20it/s]
# fonts-conda-forge-1  | 4 KB      | : 100% 1.0/1 [00:00<00:00, 21.64it/s]
# graphite2-1.3.14     | 99 KB     | : 100% 1.0/1 [00:00<00:00,  7.19it/s]
# pixman-0.40.0        | 627 KB    | : 100% 1.0/1 [00:00<00:00,  6.37it/s]
# gst-plugins-base-1.1 | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
# graph-tool-base-2.43 | 65.7 MB   | : 100% 1.0/1 [00:26<00:00, 26.91s/it]
# libpq-13.3           | 2.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
# toolz-0.11.1         | 46 KB     | : 100% 1.0/1 [00:00<00:00, 19.85it/s]
# geopandas-0.10.2     | 5 KB      | : 100% 1.0/1 [00:00<00:00, 24.04it/s]
# libogg-1.3.5         | 199 KB    | : 100% 1.0/1 [00:00<00:00,  9.44it/s]
# xorg-libxtst-1.2.3   | 31 KB     | : 100% 1.0/1 [00:00<00:00, 18.75it/s]
# freexl-1.0.6         | 48 KB     | : 100% 1.0/1 [00:00<00:00, 19.85it/s]
# xorg-libice-1.0.10   | 57 KB     | : 100% 1.0/1 [00:00<00:00, 22.04it/s]
# tk-8.6.11            | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# pillow-8.4.0         | 644 KB    | : 100% 1.0/1 [00:00<00:00,  8.72it/s]
# libcurl-7.79.1       | 335 KB    | : 100% 1.0/1 [00:00<00:00,  9.72it/s]
# numpy-1.21.3         | 6.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.61s/it]
# fonts-conda-ecosyste | 4 KB      | : 100% 1.0/1 [00:00<00:00, 18.90it/s]
# xorg-recordproto-1.1 | 7 KB      | : 100% 1.0/1 [00:00<00:00, 24.67it/s]
# sqlite-3.36.0        | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.33it/s]
# pkg-config-0.29.2    | 120 KB    | : 100% 1.0/1 [00:00<00:00, 10.36it/s]
# pyparsing-3.0.4      | 78 KB     | : 100% 1.0/1 [00:00<00:00, 10.86it/s]
# bs4-4.10.0           | 4 KB      | : 100% 1.0/1 [00:00<00:00, 22.45it/s]
# nspr-4.32            | 231 KB    | : 100% 1.0/1 [00:00<00:00, 10.00it/s]
# openssl-1.1.1l       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.22it/s]
# libtiff-4.3.0        | 614 KB    | : 100% 1.0/1 [00:00<00:00,  5.94it/s]
# librsvg-2.52.2       | 5.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
# libarchive-3.5.2     | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
# seaborn-0.11.2       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 27.07it/s]
# libwebp-1.2.1        | 84 KB     | : 100% 1.0/1 [00:00<00:00, 17.19it/s]
# networkx-2.6.3       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.03it/s]
# mapclassify-2.4.3    | 36 KB     | : 100% 1.0/1 [00:00<00:00, 18.74it/s]
# libdeflate-1.8       | 67 KB     | : 100% 1.0/1 [00:00<00:00, 19.62it/s]
# xorg-libxrender-0.9. | 32 KB     | : 100% 1.0/1 [00:00<00:00, 15.90it/s]
# font-ttf-inconsolata | 94 KB     | : 100% 1.0/1 [00:00<00:00, 18.45it/s]
# libssh2-1.10.0       | 233 KB    | : 100% 1.0/1 [00:00<00:00,  9.95it/s]
# xorg-libx11-1.7.2    | 941 KB    | : 100% 1.0/1 [00:00<00:00,  4.32it/s]
# atk-1.0-2.36.0       | 560 KB    | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
# hdf4-4.2.15          | 950 KB    | : 100% 1.0/1 [00:00<00:00,  4.07it/s]
# g-ir-build-tools-1.6 | 247 KB    | : 100% 1.0/1 [00:00<00:00,  7.18it/s]
# gettext-0.21.0       | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  5.52it/s]
# descartes-1.1.0      | 7 KB      | : 100% 1.0/1 [00:00<00:00, 26.00it/s]
# at-spi2-atk-2.38.0   | 332 KB    | : 100% 1.0/1 [00:00<00:00,  8.12it/s]
# scipy-1.7.1          | 21.7 MB   | : 100% 1.0/1 [00:04<00:00,  4.80s/it]
# libspatialite-5.0.1  | 4.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# lcms2-2.12           | 443 KB    | : 100% 1.0/1 [00:00<00:00,  8.30it/s]
# gtk3-3.24.29         | 9.7 MB    | : 100% 1.0/1 [00:02<00:00,  2.81s/it]
# attrs-21.2.0         | 44 KB     | : 100% 1.0/1 [00:00<00:00, 19.32it/s]
# gtk2-2.24.33         | 7.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.01s/it]
# gts-0.7.6            | 411 KB    | : 100% 1.0/1 [00:00<00:00,  7.75it/s]
# cligj-0.7.2          | 10 KB     | : 100% 1.0/1 [00:00<00:00, 20.53it/s]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 18.63it/s]
# libclang-11.1.0      | 19.2 MB   | : 100% 1.0/1 [00:04<00:00,  4.52s/it]
# at-spi2-core-2.40.3  | 643 KB    | : 100% 1.0/1 [00:00<00:00,  6.05it/s]
# pyqt-5.12.3          | 21 KB     | : 100% 1.0/1 [00:00<00:00, 18.43it/s]
# sigcpp-2.0-2.10.7    | 190 KB    | : 100% 1.0/1 [00:00<00:00,  8.20it/s]
# cfitsio-3.470        | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# libwebp-base-1.2.1   | 845 KB    | : 100% 1.0/1 [00:00<00:00,  4.41it/s]
# threadpoolctl-3.0.0  | 17 KB     | : 100% 1.0/1 [00:00<00:00, 22.50it/s]
# kiwisolver-1.3.2     | 78 KB     | : 100% 1.0/1 [00:00<00:00, 20.06it/s]
# libgd-2.3.3          | 279 KB    | : 100% 1.0/1 [00:00<00:00,  9.49it/s]
# shapely-1.8.0        | 367 KB    | : 100% 1.0/1 [00:00<00:00,  5.33it/s]
# giflib-5.2.1         | 80 KB     | : 100% 1.0/1 [00:00<00:00, 17.65it/s]
# jpeg-9d              | 266 KB    | : 100% 1.0/1 [00:00<00:00,  9.52it/s]
# typing_extensions-3. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 22.08it/s]
# libopenblas-0.3.18   | 9.6 MB    | : 100% 1.0/1 [00:02<00:00,  2.18s/it]
# patsy-0.5.2          | 188 KB    | : 100% 1.0/1 [00:00<00:00,  8.40it/s]
# markupsafe-2.0.1     | 22 KB     | : 100% 1.0/1 [00:00<00:00, 14.45it/s]
# fontconfig-2.13.1    | 357 KB    | : 100% 1.0/1 [00:00<00:00,  8.20it/s]
# openjpeg-2.4.0       | 444 KB    | : 100% 1.0/1 [00:00<00:00,  7.19it/s]
# gstreamer-1.18.5     | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
# pyqtchart-5.12       | 256 KB    | : 100% 1.0/1 [00:00<00:00,  9.53it/s]
# click-plugins-1.1.1  | 9 KB      | : 100% 1.0/1 [00:00<00:00, 24.57it/s]
# pyqt-impl-5.12.3     | 5.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
# hicolor-icon-theme-0 | 14 KB     | : 100% 1.0/1 [00:00<00:00, 17.02it/s]
# poppler-data-0.4.11  | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
# lerc-3.0             | 216 KB    | : 100% 1.0/1 [00:00<00:00, 10.75it/s]
# libpysal-4.5.1       | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.00it/s]
# libvorbis-1.3.7      | 287 KB    | : 100% 1.0/1 [00:00<00:00, 10.46it/s]
# graphviz-2.49.1      | 3.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# zstd-1.5.0           | 490 KB    | : 100% 1.0/1 [00:00<00:00,  7.57it/s]
# pyproj-3.2.1         | 499 KB    | : 100% 1.0/1 [00:00<00:00,  5.63it/s]
# sparsehash-2.0.4     | 86 KB     | : 100% 1.0/1 [00:00<00:00, 10.93it/s]
# readline-8.1         | 295 KB    | : 100% 1.0/1 [00:00<00:00, 10.24it/s]
# xorg-libxext-1.3.4   | 54 KB     | : 100% 1.0/1 [00:00<00:00, 21.85it/s]
# freetype-2.11.0      | 618 KB    | : 100% 1.0/1 [00:00<00:00,  8.96it/s]
# branca-0.4.2         | 26 KB     | : 100% 1.0/1 [00:00<00:00, 21.53it/s]
# xorg-renderproto-0.1 | 8 KB      | : 100% 1.0/1 [00:00<00:00, 25.73it/s]
# scikit-learn-1.0.1   | 7.9 MB    | : 100% 1.0/1 [00:02<00:00,  2.31s/it]
# libglib-2.68.4       | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# xyzservices-2021.10. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 17.62it/s]
# libllvm11-11.1.0     | 29.1 MB   | : 100% 1.0/1 [00:06<00:00,  6.46s/it]
# spectra-0.0.11       | 19 KB     | : 100% 1.0/1 [00:00<00:00, 26.08it/s]
# xorg-xproto-7.0.31   | 72 KB     | : 100% 1.0/1 [00:00<00:00, 18.19it/s]
# font-ttf-ubuntu-0.83 | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.52it/s]
# folium-0.12.0        | 64 KB     | : 100% 1.0/1 [00:00<00:00, 14.84it/s]
# json-c-0.15          | 274 KB    | : 100% 1.0/1 [00:00<00:00, 11.82it/s]
# ...
# expat-2.4.1          | 182 KB    | : 100% 1.0/1 [00:00<00:00, 13.76it/s]
# wordcloud-1.8.1      | 189 KB    | : 100% 1.0/1 [00:00<00:00, 10.62it/s]
# geotiff-1.7.0        | 298 KB    | : 100% 1.0/1 [00:00<00:00,  8.70it/s]
# qt-5.12.9            | 99.5 MB   | : 100% 1.0/1 [00:23<00:00, 23.21s/it]
# munch-2.5.0          | 12 KB     | : 100% 1.0/1 [00:00<00:00, 18.56it/s]
# olefile-0.46         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 24.02it/s]
# matplotlib-3.4.3     | 7 KB      | : 100% 1.0/1 [00:00<00:00, 26.32it/s]
# poppler-21.09.0      | 17.1 MB   | : 100% 1.0/1 [00:03<00:00,  3.37s/it]
# pandas-1.3.4         | 12.7 MB   | : 100% 1.0/1 [00:03<00:00,  3.84s/it]
# xorg-kbproto-1.0.7   | 26 KB     | : 100% 1.0/1 [00:00<00:00, 19.74it/s]
# nss-3.71             | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.93it/s]
# libgirepository-1.68 | 305 KB    | : 100% 1.0/1 [00:00<00:00,  9.89it/s]
# gobject-introspectio | 909 KB    | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
# boost-1.74.0         | 342 KB    | : 100% 1.0/1 [00:00<00:00,  5.92it/s]
# jinja2-3.0.2         | 99 KB     | : 100% 1.0/1 [00:00<00:00, 13.96it/s]
# cycler-0.11.0        | 10 KB     | : 100% 1.0/1 [00:00<00:00, 26.49it/s]
# jbig-2.1             | 43 KB     | : 100% 1.0/1 [00:00<00:00, 19.04it/s]
# libkml-1.3.0         | 591 KB    | : 100% 1.0/1 [00:00<00:00,  4.27it/s]
# matplotlib-base-3.4. | 7.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
# xorg-fixesproto-5.0  | 8 KB      | : 100% 1.0/1 [00:00<00:00, 24.08it/s]
# cairomm-1.12.2       | 11 KB     | : 100% 1.0/1 [00:00<00:00, 22.58it/s]
# zipp-3.6.0           | 12 KB     | : 100% 1.0/1 [00:00<00:00, 25.70it/s]
# libgfortran-ng-11.2. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 23.48it/s]
# pygobject-3.40.1     | 286 KB    | : 100% 1.0/1 [00:00<00:00,  7.12it/s]
# pyqtwebengine-5.12.1 | 175 KB    | : 100% 1.0/1 [00:00<00:00, 11.65it/s]
# libopus-1.3.1        | 255 KB    | : 100% 1.0/1 [00:00<00:00, 11.53it/s]
# tzdata-2021e         | 121 KB    | : 100% 1.0/1 [00:00<00:00,  8.47it/s]
# colormath-3.0.0      | 34 KB     | : 100% 1.0/1 [00:00<00:00, 19.79it/s]
# boost-cpp-1.74.0     | 16.3 MB   | : 100% 1.0/1 [00:07<00:00,  7.91s/it]
# graph-tool-2.43      | 26 KB     | : 100% 1.0/1 [00:00<00:00, 11.46it/s]
# libcblas-3.9.0       | 12 KB     | : 100% 1.0/1 [00:00<00:00, 22.83it/s]
# libxml2-2.9.12       | 772 KB    | : 100% 1.0/1 [00:00<00:00,  5.26it/s]
# postgresql-13.3      | 5.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
# cytoolz-0.11.0       | 403 KB    | : 100% 1.0/1 [00:00<00:00,  7.05it/s]
# importlib-metadata-4 | 32 KB     | : 100% 1.0/1 [00:00<00:00, 22.81it/s]
# gmp-6.2.1            | 806 KB    | : 100% 1.0/1 [00:00<00:00,  4.72it/s]
# zlib-1.2.11          | 86 KB     | : 100% 1.0/1 [00:00<00:00, 19.53it/s]
# libevent-2.1.10      | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.62it/s]
# xorg-libsm-1.2.3     | 26 KB     | : 100% 1.0/1 [00:00<00:00, 20.65it/s]
# kealib-1.4.14        | 186 KB    | : 100% 1.0/1 [00:00<00:00, 13.82it/s]
# tzcode-2021e         | 69 KB     | : 100% 1.0/1 [00:00<00:00, 22.89it/s]
# click-8.0.3          | 145 KB    | : 100% 1.0/1 [00:00<00:00, 13.40it/s]
# statsmodels-0.13.0   | 11.4 MB   | : 100% 1.0/1 [00:03<00:00,  3.13s/it]
# libtool-2.4.6        | 511 KB    | : 100% 1.0/1 [00:00<00:00,  5.35it/s]
# beautifulsoup4-4.10. | 77 KB     | : 100% 1.0/1 [00:00<00:00, 14.02it/s]
# libdap4-3.20.6       | 11.3 MB   | : 100% 1.0/1 [00:02<00:00,  2.34s/it]
# pycairo-1.20.1       | 77 KB     | : 100% 1.0/1 [00:00<00:00, 19.49it/s]
# tornado-6.1          | 646 KB    | : 100% 1.0/1 [00:00<00:00,  3.68it/s]
# g-ir-host-tools-1.68 | 102 KB    | : 100% 1.0/1 [00:00<00:00, 11.54it/s]
# epoxy-1.5.9          | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.41it/s]
# liblapack-3.9.0      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 17.06it/s]
# libzlib-1.2.11       | 59 KB     | : 100% 1.0/1 [00:00<00:00, 19.36it/s]
# libgfortran5-11.2.0  | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  2.24it/s]
# mysql-libs-8.0.27    | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# hdf5-1.12.1          | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# alsa-lib-1.2.3       | 560 KB    | : 100% 1.0/1 [00:00<00:00,  6.17it/s]
# xorg-libxfixes-5.0.3 | 18 KB     | : 100% 1.0/1 [00:00<00:00, 24.70it/s]
# libpng-1.6.37        | 359 KB    | : 100% 1.0/1 [00:00<00:00,  8.28it/s]
# librttopo-1.1.0      | 235 KB    | : 100% 1.0/1 [00:00<00:00,  9.24it/s]
# libnsl-2.0.0         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 17.95it/s]
# xorg-inputproto-2.3. | 18 KB     | : 100% 1.0/1 [00:00<00:00, 19.51it/s]
# seaborn-base-0.11.2  | 223 KB    | : 100% 1.0/1 [00:00<00:00,  9.39it/s]
# glib-tools-2.68.4    | 86 KB     | : 100% 1.0/1 [00:00<00:00, 19.10it/s]
# xorg-xextproto-7.3.0 | 27 KB     | : 100% 1.0/1 [00:00<00:00, 20.23it/s]
# done
# done
# -
# |
# \
# done
# - Ran pip subprocess with arguments:
# ['/usr/local/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/aves_git/condaenv.8fpqqvxe.requirements.txt']
# Pip subprocess output:
# Collecting git+https://github.com/mims-harvard/scikit-fusion (from -r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 7))
#   Cloning https://github.com/mims-harvard/scikit-fusion to /tmp/pip-req-build-05d125cm
# Collecting git+https://github.com/zorzalerrante/aves (from -r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 8))
#   Cloning https://github.com/zorzalerrante/aves to /tmp/pip-req-build-6p8tx_vd
# Collecting bezier
#   Downloading bezier-2021.2.12-cp37-cp37m-manylinux2010_x86_64.whl (1.4 MB)
# Collecting scattertext
#   Downloading scattertext-0.1.4-py3-none-any.whl (7.3 MB)
# Collecting KDEpy
#   Downloading KDEpy-1.1.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (387 kB)
# Collecting adjustText
#   Downloading adjustText-0.7.3.tar.gz (7.5 kB)
# Collecting contextily
#   Downloading contextily-1.2.0-py3-none-any.whl (16 kB)
# Collecting matplotlib-scalebar
#   Downloading matplotlib_scalebar-0.7.2-py2.py3-none-any.whl (17 kB)
# Collecting pymunk
#   Downloading pymunk-6.2.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (976 kB)
# Collecting emoji
#   Downloading emoji-1.6.1.tar.gz (170 kB)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/site-packages (from scikit-fusion==0.2.1->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 7)) (1.21.3)
# Requirement already satisfied: scipy>=0.12.0 in /usr/local/lib/python3.7/site-packages (from scikit-fusion==0.2.1->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 7)) (1.7.1)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/site-packages (from scikit-fusion==0.2.1->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/site-packages (from adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (3.4.3)
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/site-packages (from contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (8.4.0)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.7/site-packages (from contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (2021.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/site-packages (from matplotlib->adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib->adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->adjustText->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 4)) (1.15.0)
# Collecting cffi>=1.15.0
#   Downloading cffi-1.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (427 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.15.0->pymunk->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 9)) (2.20)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (1.3.4)
# Collecting gensim>=4.0.0
#   Downloading gensim-4.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
# Collecting flashtext
#   Downloading flashtext-2.7.tar.gz (14 kB)
# Collecting mock
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/site-packages (from scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (0.13.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.7/site-packages (from mercantile->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (8.0.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/site-packages (from click>=3.0->mercantile->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->click>=3.0->mercantile->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->click>=3.0->mercantile->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas->scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/site-packages (from rasterio->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (2020.12.5)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.7/site-packages (from rasterio->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/site-packages (from rasterio->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (0.7.2)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from rasterio->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (49.6.0.post20210108)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/site-packages (from rasterio->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (21.2.0)
# Collecting affine
#   Downloading affine-2.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->contextily->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 5)) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/site-packages (from statsmodels->scattertext->-r /content/aves_git/condaenv.8fpqqvxe.requirements.txt (line 2)) (0.5.2)
# Building wheels for collected packages: aves, scikit-fusion, adjustText, emoji, flashtext
#   Building wheel for aves (setup.py): started
#   Building wheel for aves (setup.py): finished with status 'done'
#   Created wheel for aves: filename=aves-1.2.0-py3-none-any.whl size=58082 sha256=2535186c0ec29922fc085a082017a256ba2e464de7e4d4ac32030c1ee84ea66c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hhe7phzv/wheels/9e/4e/28/12d2564c9ecb6f68cda7739d9243c32f00e29fee5286d5ce11
#   Building wheel for scikit-fusion (setup.py): started
#   Building wheel for scikit-fusion (setup.py): finished with status 'done'
#   Created wheel for scikit-fusion: filename=scikit_fusion-0.2.1-py2.py3-none-any.whl size=6749544 sha256=33e170013c75cecbd8a18a398152c659ca2b02a8e43c94c320d36910c7da9046
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hhe7phzv/wheels/f2/ee/45/e35ec07caf15a0e1021c3552409df3d3ba950c038c5e08341c
#   Building wheel for adjustText (setup.py): started
#   Building wheel for adjustText (setup.py): finished with status 'done'
#   Created wheel for adjustText: filename=adjustText-0.7.3-py3-none-any.whl size=7098 sha256=54473c7d3c6c9bad40306e53653d95801f5f1cf87bca7e3f8f3fc14235c10e12
#   Stored in directory: /root/.cache/pip/wheels/2f/98/32/afbf902d8f040fadfdf0a44357e4ab750afe165d873bf5893d
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.6.1-py3-none-any.whl size=169294 sha256=312f400536fc437f6e619386eedfb1b11638a91cbdd4da0e2ba9fe92106bb936
#   Stored in directory: /root/.cache/pip/wheels/ea/5f/d3/03d313ddb3c2a1a427bb4690f1621eea60fe6f2a30cc95940f
#   Building wheel for flashtext (setup.py): started
#   Building wheel for flashtext (setup.py): finished with status 'done'
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9299 sha256=99898f2c9088b089ef5e55e953bde58c2b204d67fcc52190d254ff35600de1d8
#   Stored in directory: /root/.cache/pip/wheels/cb/19/58/4e8fdd0009a7f89dbce3c18fff2e0d0fa201d5cdfd16f113b7
# Successfully built aves scikit-fusion adjustText emoji flashtext
# Installing collected packages: snuggs, smart-open, geographiclib, affine, rasterio, mock, mercantile, geopy, gensim, flashtext, cffi, scikit-fusion, scattertext, pymunk, matplotlib-scalebar, KDEpy, emoji, contextily, bezier, aves, adjustText
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.14.5
#     Uninstalling cffi-1.14.5:
#       Successfully uninstalled cffi-1.14.5
# Successfully installed KDEpy-1.1.0 adjustText-0.7.3 affine-2.3.0 aves-1.2.0 bezier-2021.2.12 cffi-1.15.0 contextily-1.2.0 emoji-1.6.1 flashtext-2.7 gensim-4.1.2 geographiclib-1.52 geopy-2.2.0 matplotlib-scalebar-0.7.2 mercantile-1.2.1 mock-4.0.3 pymunk-6.2.1 rasterio-1.2.10 scattertext-0.1.4 scikit-fusion-0.2.1 smart-open-5.2.1 snuggs-1.4.7
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !pip3 install geopandas
# !pip3 install pandasql
# !pip3 install seaborn
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/site-packages (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (49.6.0.post20210108)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/site-packages (from click>=4.0->fiona>=1.8->geopandas) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (1.21.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.10.0.2)
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from pandasql) (1.21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from pandasql) (1.3.4)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.26-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 6.6 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/site-packages (from sqlalchemy->pandasql) (4.8.1)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (150 kB)
#      |████████████████████████████████| 150 kB 43.3 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy->pandasql) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy->pandasql) (3.6.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26818 sha256=5b3873cc1a4e2f0ae25b5819443dd16db91026ef43122934500799f69336c9dc
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# Installing collected packages: greenlet, sqlalchemy, pandasql
# Successfully installed greenlet-1.1.2 pandasql-0.7.3 sqlalchemy-1.4.26
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.7/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/site-packages (from seaborn) (1.21.3)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import geopandas as gpd
import warnings
import shapely
from sklearn.preprocessing import normalize
import datetime

# %%
def decode_column(df, fname, col_name, index_col='id', value_col=None, sep=';', encoding='utf-8'):
    '''
    param :df: DataFrame del que leeremos una columna.
    param :fname: nombre del archivo que contiene los valores a decodificar.
    param :col_name: nombre de la columna que queremos decodificar.
    param :index_col: nombre de la columna en el archivo @fname que tiene los índices que codifican @col_name
    param :value_col: nombre de la columna en el archivo @fname que tiene los valores decodificados
    param :sep: carácter que separa los valores en @fname. 
    param :encoding: identificación del _character set_ que utiliza el archivo. Usualmente es utf-8, si no funciona,
                     se puede probar con iso-8859-1.
    '''
    if value_col is None:
        value_col = 'value'
        
    values_df = pd.read_csv(fname, sep=sep, index_col=index_col, names=[index_col, value_col], header=0,
                            dtype={index_col: np.float64}, encoding=encoding)
    
    src_df = df.loc[:,(col_name,)]
    
    return src_df.join(values_df, on=col_name)[value_col]

# %%
def convert_datatype(df, lista_columnas):
    for column in lista_columnas:
        df[column] = df[column].str.replace(",", ".").astype(float)
    return df

# %%
def imputar_coordenadas_centroide_zat(df, latitud, longitud, zat, zat_shp):
    mask = df[latitud].isnull() | df[longitud].isnull()
    ids_latitud_vacia = df[mask].index
    working_df = pd.merge(df, city_shp[[zat_shp, 'x_coord', 'y_coord']], left_on=zat, right_on=zat_shp, how='left')
    df.loc[ids_latitud_vacia, latitud] = working_df.loc[ids_latitud_vacia, 'x_coord']
    df.loc[ids_latitud_vacia, longitud] = working_df.loc[ids_latitud_vacia, 'y_coord']
    return df

# %%
def mapear_binarias(row, column):
    if row[column] == 'N':
        return 'No'
    elif row[column] == 'S':
        return 'Si'
    else:
        return 'Sin dato'

# %%
def mapear_vacios(row, column):
    if pd.isna(row[column])==True:
        return 'Sin información'
    else:
        return row[column]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Caracterización de los datos
#
# Los datos utilizados en este cuaderno corresponden a los resultados de la Encuesta Origen-Destino de Montevideo, Uruguay del 2009.
# A partir de estos datos se calcularan indicadores en tres niveles: de Cantidad de Viajes, y de Tiempo de Viajes.

# %% [markdown]
# ### Importando datos

# %% [markdown]
# En esta sección, importamos todos los datos necesarios para el cálculo de indicadores.
# Para el caso de Montevideo 2009, los archivos son de cs.
#
# Cabe destacar que para esta EOD tenemos data a nivel de:
# - Viajes
# - Etapas
# - Personas
# - Hogares

# %%
data_path = '/content/drive/MyDrive/Carpeta compartida (clon Teams)/Ciudades/Montevideo/csv'
#data_path = '/Users/pauvasquezh/Dropbox/Proyectos/eod_analysis/Carpeta compartida (clon Teams)/Montevideo/csv'

# %%
# Matriz de viajes
data_viajes = pd.read_csv(data_path + '/Encuesta viajes.csv', sep=',', encoding='latin1')
#data_viajes = convert_datatype(data_viajes, ["LATITUD_ORIGEN", "LATITUD_DESTINO", "LONGITUD_ORIGEN", "LONGITUD_DESTINO", 'PONDERADOR_CALIBRADO_VIAJES', 'FE_TOTAL', 'FACTOR_AJUSTE_TRANSMILENIO', 'PONDERADOR_CALIBRADO'])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (32,33,34,48,63,76) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Matriz de personas
data_personas = pd.read_csv(data_path + '/Encuesta personas.csv', sep=',', encoding='latin1')
data_personas.head(2)
#data_personas = convert_datatype(data_personas, ['PONDERADOR_CALIBRADO'])
# Out:
#    EncuestaPersona_id  EncuestaHogar_ID  ... ¿Se movió?  Ponderacion
# 0                  55                51  ...         SI   233.358348
# 1                  68                67  ...       #N/D   227.738047
#
# [2 rows x 41 columns]

# %%
# Matriz de encuestas
data_encuestas = pd.read_csv(data_path + '/Encuesta hogares.csv', sep=',', encoding='latin1')
data_encuestas.head(2)
#data_personas = convert_datatype(data_personas, ['PONDERADOR_CALIBRADO'])
# Out:
#    EncuestaHogar_id  DEPARTAMENTO  Estrato  ...  MotoECH ZonaIMM  Ponderacion
# 0                51             1        1  ...        1   Oeste   233.358348
# 1                62             1        2  ...        2   Oeste   146.764519
#
# [2 rows x 17 columns]

# %% [markdown]
# ### Preparación de los datos

# %% [markdown]
# #### Viajes

# %% [markdown]
# En esta etapa nos enfocaremos en preparar los datos con respecto a viajes.
# En particular, nos enfocamos en limpiar y estandarizar los datos para las columnas que son relevantes para el cálculo de indicadores.

# %%
data_viajes.MEDIOTRANSPORTE = decode_column(data_viajes, data_path + '/data_dictionaries/modotransporte.csv', 'MEDIOTRANSPORTE')
data_viajes.MEDIOTRANSPORTE.unique()
# Out:
# array(['Automovil pasajero', 'Omnibus', 'Moto pasajero', 'A pie',
#        'Bicicleta', 'Taxi', 'Moto conductor', 'Automovil conductor',
#        'Bus escolar', 'Bus empresa', 'Traccion animal', 'Remis', 'Otro',
#        'Ferrocarril'], dtype=object)

# %%
publico_viaje = ['Omnibus','Remis', 'Ferrocarril']
privado_viaje = ['Automovil pasajero','Moto pasajero','A pie','Bicicleta', 'Taxi', 'Moto conductor', 'Automovil conductor',
       'Bus escolar', 'Bus empresa', 'Traccion animal']
peaton_viaje = ['A pie','Bicicleta','Traccion animal']
motorizado_viaje = ['Omnibus','Remis', 'Ferrocarril','Automovil pasajero','Moto pasajero','Taxi', 'Moto conductor', 'Automovil conductor','Bus escolar', 'Bus empresa']

# %%
selected_columns = ['EncuestaViaje_id', 'EncuestaHogar_id', 'EncuestaPersona_id', 'zonaimm','INICIOHORA',
       'INICIOMINUTOS', 'LLEGADAHORA', 'LLEGADAMINUTOS','TiempoTotal','NombreActividadDestino','ZATO', 'ZATD', 'MEDIOTRANSPORTE',
                    'Ponderacion']
viajes_df = data_viajes[selected_columns]

# %%
data_viajes.columns
# Out:
# Index(['EncuestaViaje_id', 'EncuestaHogar_id', 'EncuestaPersona_id', 'zonaimm',
#        'NUMEROVIAJE', 'NUMEROVIAJESIGUIENTE', 'IdViajeSiguiente', 'INICIOHORA',
#        'INICIOMINUTOS', 'LLEGADAHORA',
#        ...
#        'TamanoHogar', 'PersonasenHogar', 'AutosenHogar', 'MotosenHogar',
#        'OtrosenHogar', 'VehiculosenHogar', 'Estrato', 'Ingreso Familiar',
#        'Quintil ingresos', 'Ponderacion'],
#       dtype='object', length=141)

# %%
viajes_df['Quintil'] = data_viajes['Quintil ingresos']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
viajes_df['Quintil'] = decode_column(viajes_df, data_path + '/data_dictionaries/quintil.csv', 'Quintil')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
viajes_df.shape
# Out:
# (8508, 15)

# %%
print('Contando valores nulos por atributo')
for column in selected_columns:
    print('{}: {}'.format(column, viajes_df[column].isna().sum()))
# Out:
# Contando valores nulos por atributo
# EncuestaViaje_id: 0
# EncuestaHogar_id: 0
# EncuestaPersona_id: 0
# zonaimm: 1954
# INICIOHORA: 2
# INICIOMINUTOS: 2
# LLEGADAHORA: 2
# LLEGADAMINUTOS: 2
# TiempoTotal: 2
# NombreActividadDestino: 2
# ZATO: 10
# ZATD: 0
# MEDIOTRANSPORTE: 0
# Ponderacion: 0

# %%
# Llenado de coordenadas para datos vacíos, se imputará centroide del ZAT correspondiente.

# %%
#viajes_df = imputar_coordenadas_centroide_zat(viajes_df, 'LATITUD_ORIGEN', 'LONGITUD_ORIGEN', 'ZAT_ORIGEN')
#viajes_df = imputar_coordenadas_centroide_zat(viajes_df, 'LATITUD_DESTINO', 'LONGITUD_DESTINO','ZAT_DESTINO')

# %%
# Limpiando datos de variables binarias

# %%
def pico_habil(row):
    if row['INICIOHORA'] >= 7.0 and row['INICIOHORA'] <= 9.0:
        return'Si'
    else:
        return 'No'
    
viajes_df['PICO_HABIL'] = viajes_df.apply(lambda row: pico_habil(row), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
mask = viajes_df['ZATO'].isnull() | viajes_df['ZATD'].isnull()
viajes_df = viajes_df[~mask]

# %%
viajes_df['Intra_Inter'] = viajes_df.apply(lambda row: 'Intra' if row['ZATO'] == row['ZATD'] else 'Inter', axis=1)

# %%
def publico_privado(row, column, publico, privado):
    if row[column] in (publico):
        return 'Público'
    elif row[column] in (privado):
        return 'Privado'
    else:
        return 'Otro'
    
viajes_df['publico_privado'] = viajes_df.apply(lambda row: publico_privado(row, 'MEDIOTRANSPORTE', publico_viaje, privado_viaje), axis=1)

# %%
# Clasificando los viajes como motorizado o no motorizado según medio
def motorizado(row, column, no_motorizado, motorizado):
    if row[column] in (motorizado):
        return 'Motorizado'
    elif row[column] in (no_motorizado):
        return 'No Motorizado'
    else:
        return 'Otro'
    
viajes_df['motorizado'] = viajes_df.apply(lambda row: motorizado(row, 'MEDIOTRANSPORTE', peaton_viaje,motorizado_viaje), axis=1)

# %%
viajes_df['duracion'] = (viajes_df['TiempoTotal'])

# %%
print('Contando valores nulos por atributo')
for column in viajes_df.columns:
    print('{}: {}'.format(column, viajes_df[column].isna().sum()))
# Out:
# Contando valores nulos por atributo
# EncuestaViaje_id: 0
# EncuestaHogar_id: 0
# EncuestaPersona_id: 0
# zonaimm: 1951
# INICIOHORA: 1
# INICIOMINUTOS: 1
# LLEGADAHORA: 1
# LLEGADAMINUTOS: 1
# TiempoTotal: 1
# NombreActividadDestino: 0
# ZATO: 0
# ZATD: 0
# MEDIOTRANSPORTE: 0
# Ponderacion: 0
# Quintil: 0
# PICO_HABIL: 0
# Intra_Inter: 0
# publico_privado: 0
# motorizado: 0
# duracion: 1

# %%
viajes_df.shape
# Out:
# (8498, 20)

# %% [markdown]
# #### Personas y Hogares

# %% [markdown]
# En esta etapa nos enfocaremos en preparar los datos con respecto a personas.
# En particular, nos enfocamos en limpiar y estandarizar los datos para las columnas que son relevantes para el cálculo de indicadores.

# %%
data_personas.columns
# Out:
# Index(['EncuestaPersona_id', 'EncuestaHogar_ID', 'zonaimm', 'ZatHogar',
#        'MZatHogar', 'DptoHogar', 'estrato', 'Anillo', 'Idpersonaech',
#        'PARENTESCO', 'FECHAVIAJES', 'LUGAR4MANANAENUM', 'zat4am', 'Edad',
#        'Edad052009', 'NacimientoAnio', 'sexo', 'TamanoHogar',
#        'PersonasenHogar', 'Vehiculosenhogar', 'TipousuarioModo', 'Preescolar',
#        'PrimariaComun', 'PrimariaEspecial', 'CicloBasicoLiceo',
#        'BachillerSecundario', 'BachillerTecnilogico', 'Tecnico', 'Profesorado',
#        'Universitario', 'Terciario', 'Posgrado', 'EstudioPrincipal',
#        'AsistenciaInstitutoEducativo', 'Jubilado', 'Pensionista', 'Rentista',
#        'Estudiante', 'QuehaceresEnCasa', '¿Se movió?', 'Ponderacion'],
#       dtype='object')

# %%
selected_columns = ['EncuestaPersona_id', 'sexo', 'Ponderacion', 'Edad', 'EncuestaHogar_ID','AsistenciaInstitutoEducativo', 'Jubilado', 'Pensionista', 'Rentista',
       'Estudiante', 'QuehaceresEnCasa']
personas_df = data_personas[selected_columns]

# %%
personas_df['sexo'] = decode_column(personas_df, data_path + '/data_dictionaries/gender.csv', 'sexo')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_encuestas.columns
# Out:
# Index(['EncuestaHogar_id', 'DEPARTAMENTO', 'Estrato', 'IdTamanoHogar',
#        'TamanoHogar', 'Personas', 'PersonasMenor4', 'PersonasDesde4', 'Autos',
#        'Motos', 'Otros', 'Vehiculos', 'EspaciosEstacionamiento', 'AutoECH',
#        'MotoECH', 'ZonaIMM', 'Ponderacion'],
#       dtype='object')

# %%
selected_columns = ['EncuestaHogar_id', 'Estrato']
encuestas_df = data_encuestas[selected_columns]

# %%
personas_df = pd.merge(personas_df, encuestas_df, left_on='EncuestaHogar_ID', right_on='EncuestaHogar_id', how='left')

# %%
viajes_personas = pd.merge(viajes_df, personas_df, on=['EncuestaPersona_id', 'EncuestaHogar_id'], how='left')

# %%
print('Contando valores nulos por atributo')
for column in viajes_personas.columns:
    print('{}: {}'.format(column, viajes_personas[column].isna().sum()))
# Out:
# Contando valores nulos por atributo
# EncuestaViaje_id: 0
# EncuestaHogar_id: 0
# EncuestaPersona_id: 0
# zonaimm: 1951
# INICIOHORA: 1
# INICIOMINUTOS: 1
# LLEGADAHORA: 1
# LLEGADAMINUTOS: 1
# TiempoTotal: 1
# NombreActividadDestino: 0
# ZATO: 0
# ZATD: 0
# MEDIOTRANSPORTE: 0
# Ponderacion_x: 0
# Quintil: 0
# PICO_HABIL: 0
# Intra_Inter: 0
# publico_privado: 0
# motorizado: 0
# duracion: 1
# sexo: 0
# Ponderacion_y: 0
# Edad: 0
# EncuestaHogar_ID: 0
# AsistenciaInstitutoEducativo: 211
# Jubilado: 211
# Pensionista: 211
# Rentista: 211
# Estudiante: 211
# QuehaceresEnCasa: 211
# Estrato: 0

# %%
viajes_personas.to_csv(data_path + '/viajes_personas_montevideo_2009.csv', index=False)

# %% [markdown]
# ### Descripción de los datos

# %% [markdown]
# ¿Quienes son las personas encuestadas?

# %%
personas_df.Edad.describe()
# Out:
# count    4052.000000
# mean       38.079961
# std        23.280767
# min         0.000000
# 25%        19.000000
# 50%        36.000000
# 75%        56.000000
# max        97.000000
# Name: Edad, dtype: float64

# %%
def age_cohorts(row, age_column):
    if row[age_column] < 18:
        return '<18'
    elif row[age_column] <=29 and row[age_column] > 18:
        return '18-29'
    elif row[age_column] <=60 and row[age_column] > 29:
        return '30-60'
    elif row[age_column] > 60 and row[age_column] < 100:
        return '>60'
    else:
        return 'No declarado'

# %%
def normalize_rows(df):
    return df.pipe(lambda x: pd.DataFrame(normalize(df, axis=1, norm='l1'), columns=df.columns, index=df.index))

# %%
personas_df['age_cohort'] = personas_df.apply(lambda row: age_cohorts(row, 'Edad'), axis=1)

# %%
order = ['<18', '18-29', '30-60','>60','No declarado']
ax = (personas_df.groupby(['age_cohort']).size().loc[reversed(order)]
 .plot(kind='barh', figsize=(6,3)))
ax.set_xlabel("# de Encuestados")
ax.set_ylabel(" ")
ax.set_title("Distribución de Personas encuestadas por grupo de edad")
sns.despine()

# %% [markdown]
# La mayor parte de los encuestados tienen entre 30-60 años de edad.

# %%
ax = (personas_df.groupby(['sexo']).size()
 .plot(kind='barh', figsize=(6,3)))
ax.set_xlabel("# de Encuestados")
ax.set_ylabel(" ")
ax.set_title("Distribución de Personas encuestadas por sexo")
sns.despine()

# %%
ax = (personas_df.groupby(['age_cohort', 'sexo']).size().unstack()
 .pipe(normalize_rows)
 .plot(kind='barh', stacked=True, figsize=(6, 3)))
ax.set_xlabel("% de Encuestados")
ax.set_ylabel(" ")
ax.set_title("Distribución de Personas encuestadas por sexo y edad")
sns.despine()

plt.legend(loc=0, bbox_to_anchor=(1.0, 0.5))

# %%
ax = personas_df[['AsistenciaInstitutoEducativo', 'Jubilado', 'Pensionista', 'Rentista',
       'Estudiante', 'QuehaceresEnCasa']].replace(2,0).T.sum(axis=1).sort_values().plot(kind='barh', figsize=(6,3))
ax.set_xlabel("# de Encuestados")
ax.set_ylabel(" ")
ax.set_title("Distribución de Personas encuestadas de acuerdo a Actividad Principal")
sns.despine()

# %% [markdown]
# Vemos que la mayor parte de los encuestados son en su mayoria encargados de quehaceres del hogar, con edades entre 30 y 60 años, con una cantidad equilibrada de hombres y mujeres.

# %% [markdown]
# ### Parte I: Indicadores de Cantidad de Viajes
# En esta primera parte, responderemos algunas preguntas respecto a indicadores de cantidades de viajes realizados, en días hábiles de viaje. Para esto, buscaremos responder las siguientes preguntas:
#
# 1. ¿Cuál es la tasa promedio de viajes diarios en transporte público por clasificador económico?
# 2. ¿Cuál es la tasa promedio de viajes diarios en transporte privado por clasificador económico?
# 3. ¿Cuál es la razón entre los viajes en transporte público y privado por clasificador socioeconómico?
# 4. ¿Cuál es la distribución/partición modal de los viajes por clasificador socioeconómico?

# %% [markdown]
# En esta sección, se detallarán los resultados para indicadores a nivel de viajes, separados por días hábiles de viaje, y por clasificador socioeconómico.

# %%
print('Cantidad de viajes mapeados: totales encuesta , total expandido')
viajes_habiles = viajes_personas
viajes_habiles = viajes_habiles.drop('EncuestaHogar_ID', axis=1)
print('Total Viajes Habiles: {}'.format(viajes_habiles.shape[0]), viajes_habiles['Ponderacion_x'].sum())
# Out:
# Cantidad de viajes mapeados: totales encuesta , total expandido
# Total Viajes Habiles: 8498 4262972.002677735

# %% [markdown]
# Separamos los viajes habiles y no habiles de acuerdo a si son privados o publicos

# %%
viajes_publico_habiles = viajes_habiles[viajes_habiles.MEDIOTRANSPORTE.isin(publico_viaje)]
#viajes_publico_nohabiles = viajes_nohabiles[viajes_nohabiles.MEDIO_PREDOMINANTE.isin(publico_viaje)]

viajes_privado_habiles = viajes_habiles[viajes_habiles.MEDIOTRANSPORTE.isin(privado_viaje)]
#viajes_privado_nohabiles = viajes_nohabiles[viajes_nohabiles.MEDIO_PREDOMINANTE.isin(privado_viaje)]

# %%
def weighted_mean(df, value_column, weighs_column):
    weighted_sum = (df[value_column] * df[weighs_column]).sum()
    return weighted_sum / df[weighs_column].sum()

# %%
def weighted_median(df, val, weight):
    df_sorted = df.sort_values(val)
    cumsum = df_sorted[weight].cumsum()
    cutoff = df_sorted[weight].sum() / 2.
    return df_sorted[cumsum >= cutoff][val].iloc[0]

# %% [markdown]
# #### **¿Cuál es la tasa promedio de viajes diarios en transporte público por clasificador económico?**

# %% [markdown]
# Los siguientes gráficos muestran los viajes per cápita en trasporte público durante días hábiles, por clasificador socioeconómico.

# %%
from pandasql import sqldf
def calculate_n_viajes_per_capita(df, df_str, agg_columns_str, agg_columns_lst, id_person, person_weight, trip_weight=None):
    q = "SELECT DISTINCT {}, {}, {} FROM {}".format(id_person, agg_columns_str, person_weight, df_str)
    persons = sqldf(q, globals())
    n_personas = persons.groupby(agg_columns_lst).sum()[[person_weight]].reset_index()
    n_personas[agg_columns_lst[0]] = n_personas[agg_columns_lst[0]].astype(str)
    n_viajes = df.groupby(agg_columns_lst).sum()[[trip_weight]].reset_index()
    n_viajes[agg_columns_lst[0]] = n_viajes[agg_columns_lst[0]].astype(str)
    merged = pd.merge(n_personas, n_viajes, on=agg_columns_lst, how='left')
    merged['viajes_per_capita'] = merged[trip_weight] / merged[person_weight]
    return merged

# %%
print('Viajes per cápita en transporte público')
df = calculate_n_viajes_per_capita(viajes_publico_habiles, "viajes_publico_habiles", "Quintil", ["Quintil"], 'EncuestaPersona_id', 'Ponderacion_y', 'Ponderacion_x')
g = sns.catplot(x="Quintil", y="viajes_per_capita", 
                capsize=.2, height=4, aspect=2,
                kind="point", data=df)

g.fig.suptitle('Viajes per cápita en transporte público - Día Hábil')
g.set_ylabels('# Viajes per Cápita')
g.set_xlabels('Quintil')
g.set_xticklabels(rotation=80)
g.set(ylim=(0,3))

#fig.tight_layout()
# Out:
# Viajes per cápita en transporte público

# %% [markdown]
# #### **¿Cuál es la tasa promedio de viajes diarios en transporte privado por clasificador económico?**

# %% [markdown]
# Los siguientes gráficos representan la tasa promedio de viajes diarios en el transporte privado durante días hábiles, por clasificador socioeconómico.

# %%
print('Viajes per cápita en transporte privado')
df = calculate_n_viajes_per_capita(viajes_privado_habiles, "viajes_privado_habiles", "Quintil", ["Quintil"], 'EncuestaPersona_id', 'Ponderacion_y', 'Ponderacion_x')
g = sns.catplot(x="Quintil", y="viajes_per_capita", 
                capsize=.2, height=4, aspect=2,
                kind="point", data=df)

g.fig.suptitle('Viajes per cápita en transporte privado - Día No Hábil')
g.set_ylabels('# Viajes per Cápita')
g.set_xlabels('Quintil')
g.set_xticklabels(rotation=80)
g.set(ylim=(0,4))

#fig.tight_layout()
# Out:
# Viajes per cápita en transporte privado

# %% [markdown]
# Para días hábiles, no se ve diferencia a través de la clasificación socioeconómica. En transporte privado, se ve una tendencia similar, con un aumento en el 5to clasificador.

# %% [markdown]
# #### **¿Cuál es la razón entre los viajes en transporte público y privado por clasificador socioeconómico?**

# %% [markdown]
# Los gráficos a continuación muestran la razón entre los viajes en transporte público y transporte privado durante días hábiles, por clasificador socioeconómico.

# %%
print('Razón entre los viajes en transporte público y privado - Día Hábil')

viajes_privados = viajes_privado_habiles.groupby(["Quintil"]).agg(n_privados= ('Ponderacion_x', 'sum')).reset_index()
viajes_publicos = viajes_publico_habiles.groupby(["Quintil"]).agg(n_publicos = ('Ponderacion_x', 'sum')).reset_index()
n_viajes_modo = pd.merge(viajes_privados, viajes_publicos, on='Quintil')#.set_index('CLASIFICACION_SISBEN')
n_viajes_modo['privado_sobre_publico'] = n_viajes_modo['n_privados'] / n_viajes_modo['n_publicos']

g = sns.catplot(x="Quintil", y="privado_sobre_publico",
                capsize=.2, height=4, aspect=2,
                kind="point", data=n_viajes_modo)

g.fig.suptitle('Razón entre los viajes en transporte público y privado - Día Hábil')
g.set_ylabels('Proporción de viajes privados sobre públicos')
g.set_xticklabels(rotation=80)
g.set_xlabels('Quintil')
g.set(ylim=(0,4))

#fig.tight_layout()
# Out:
# Razón entre los viajes en transporte público y privado - Día Hábil

# %% [markdown]
# Podemos notar que a mayor ingreso, mayor es el uso de viajes en transporte privado por sobre el público.

# %% [markdown]
# #### **¿Cuál es la distribución/partición modal de los viajes por clasificador socioeconómico?**

# %% [markdown]
# Las siguientes tablas y gráficos representan la partición modal de los viajes realizados en días hábiles, por clasificador socioeconómico.

# %%
print('Partición Modal de los Viajes')
df = viajes_habiles.groupby(["Quintil", 'MEDIOTRANSPORTE']).sum()['Ponderacion_x'].unstack()
#.agg(count=('MEDIO_PREDOMINANTE','count')).unstack()
df_norm = df.div(df.sum(axis=1), axis=0).fillna(0)

fig, ax = plt.subplots(figsize=(10, 5))

ax = sns.heatmap(df_norm,linewidth=0.5)

ax.set_title("Partición Modal de los Viajes - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Partición Modal de los Viajes

# %% [markdown]
# A continuación, se representa la partición modal de los viajes por tipo de transporte en días hábiles, por quintiles de ingreso de acuerdo a quintiles.

# %%
print('Partición Modal de los Viajes de acuerdo al tipo de transporte')
df = viajes_habiles.groupby(["Quintil", 'publico_privado']).sum()['Ponderacion_x'].unstack()
df_norm= df.div(df.sum(axis=1), axis=0).fillna(0)
from aves.visualization.tables import barchart

fig, ax = plt.subplots(figsize=(10,8))

barchart(
    ax, df_norm, stacked=True, normalize=False, sort_categories=True, sort_items=False
)

ax.set_title("Partición Modal de los Viajes de acuerdo al tipo de transporte (Público/Privado) - Día Hábil")
ax.set_ylim([0, 1])
ax.set_xlabel("Quintiles")
ax.set_ylabel("Fracción de los Viajes")

fig.tight_layout()
# Out:
# Partición Modal de los Viajes de acuerdo al tipo de transporte

# %%
print('Partición Modal de los Viajes de acuerdo al tipo de transporte (Motorizado/No Motorizado) - Día Hábil')
df = viajes_habiles.groupby(["Quintil", 'motorizado']).sum()['Ponderacion_x'].unstack()
df_norm = df.div(df.sum(axis=1), axis=0)
fig, ax = plt.subplots(figsize=(10, 8))

barchart(
    ax, df_norm, stacked=True, normalize=False, sort_categories=True, sort_items=False
)

ax.set_title("Partición Modal de los Viajes de acuerdo al tipo de transporte (Motorizado/No Motorizado) - Día Hábil")
ax.set_ylim([0, 1])
ax.set_xlabel("Quintil")
ax.set_ylabel("Fracción de los Viajes")

fig.tight_layout()
# Out:
# Partición Modal de los Viajes de acuerdo al tipo de transporte (Motorizado/No Motorizado) - Día Hábil

# %% [markdown]
# Se puede notar que al aumentar el ingreso familiar, aumenta el uso de modos motorizados de transporte.

# %% [markdown]
# ### Parte II: Indicadores de Tiempo de Viajes
#
# En esta primera parte, responderemos algunas preguntas respecto a indicadores de tiempo de viajes realizados, en días hábiles y no hábiles de viaje. Para esto, buscaremos responder las siguientes preguntas:
# 1. ¿Cuál es el tiempo promedio de viaje por modo y tipo de transporte?
# 2. ¿Cuál es el tiempo promedio de viaje en hora punta de mañana?
# 3. ¿Cuál es el tiempo de viaje en transporte público en hora punta de mañana?
# 4. ¿Cuál es el tiempo promedio de viaje al trabajo en transporte público?

# %% [markdown]
# En esta sección, se presentarán los indicadores de tiempo de viajes a nivel de viajes, durante días hábiles, y por clasificador socioeconómico.

# %% [markdown]
# #### **¿Cuál es el tiempo promedio de viaje por modo y tipo de transporte?**

# %% [markdown]
# A continuación, se representa el promedio y mediana en minutos de viaje por modo y tipo de transporte en días hábiles, por clasificador socioeconómico.

# %%
print('Duración promedio (en minutos) de viaje por modo - Dia Hábil')
df = viajes_habiles.groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(12, 6))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por modo - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje por modo - Dia Hábil')
df = viajes_habiles.groupby(["Quintil",  'MEDIOTRANSPORTE']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje por modo - Dia Hábil

# %%
print('Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil')
df = viajes_habiles.groupby(["Quintil", 'publico_privado']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje por tipo de transporte - Dia Hábil')
df = viajes_habiles.groupby(["Quintil", 'publico_privado']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje por tipo de transporte - Dia Hábil

# %%
print('Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil')
df = viajes_habiles.groupby(["Quintil", 'motorizado']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio de viaje por modo (Motorizado/No Motorizado) - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil

# %%
print('Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil')
df = viajes_habiles.groupby(["Quintil", 'motorizado']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana de viaje por modo (Motorizado/No Motorizado) - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por tipo de transporte - Dia Hábil

# %% [markdown]
# #### **¿Cuál es el tiempo promedio de viaje en hora punta de mañana?**

# %% [markdown]
# Estos son los resultados para el promedio y mediana en minutos de viaje en hora punta de la mañana por modo de transporte, en días hábiles, por clasificador socioeconómico.

# %%
print('Duración promedio (en minutos) de viaje por modo en hora punta - Dia Hábil')
df = viajes_habiles[viajes_habiles.PICO_HABIL=='Si'].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio de viaje hora punta mañana por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por modo en hora punta - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje por modo en hora punta - Dia Hábil')
df = viajes_habiles[viajes_habiles.PICO_HABIL=='Si'].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana de viaje hora punta mañana por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje por modo en hora punta - Dia Hábil

# %%
print('Duración promedio (en minutos) de viaje por tipo de transporte en hora punta - Dia Hábil')
df = viajes_habiles[(viajes_habiles.PICO_HABIL=='Si')].groupby(["Quintil", 'publico_privado']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje por tipo de transporte en hora punta - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje por tipo de transporte en hora punta - Dia Hábil')
df = viajes_habiles[(viajes_habiles.PICO_HABIL=='Si')].groupby(["Quintil", 'publico_privado']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana de viaje por modo - Día Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje por tipo de transporte en hora punta - Dia Hábil

# %% [markdown]
# #### **¿Cuál es el tiempo de viaje en transporte público en hora punta de mañana?**

# %% [markdown]
# A continuación, se presentan los resultados para duración promedio de viaje en hora punta de mañana en transporte público, en días hábiles, por clasificador socioeconómico.

# %%
print('Duración promedio (en minutos) de viaje al trabajo en transporte público - Dia Hábil')
mask = (viajes_habiles.publico_privado=='Público')
df = viajes_habiles[mask].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio (en minutos) de viaje en hora punta en transporte público - Dia Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje al trabajo en transporte público - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje al trabajo en transporte público - Dia Hábil')
mask = (viajes_habiles.publico_privado=='Público') & (viajes_habiles.NombreActividadDestino=='Trabajo')
df = viajes_habiles[mask].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana (en minutos) de viaje en hora punta en transporte público - Dia Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje al trabajo en transporte público - Dia Hábil

# %% [markdown]
# #### **¿Cuál es el tiempo promedio de viaje al trabajo en transporte público?**

# %% [markdown]
# A continuación, se presentan los resultados de tiempo promedio de viaje al trabajo en transporte público por modo en días hábiles, por clasificador socioeconómico.

# %%
viajes_habiles.NombreActividadDestino.unique()
# Out:
# array(['Entretenimiento', 'Hogar', 'Compras', 'Trabajo', 'Estudio',
#        'Tramites de trabajo', 'Dejar/Recoger ninos del colegio',
#        'Acompanar a alguien', 'Tramites personales',
#        'Dejar/Recoger a alguien', 'Asistencia medica/dental',
#        'Visitar a alguien', 'Ir a comer', 'Otro'], dtype=object)

# %%
print('Duración promedio (en minutos) de viaje al trabajo en transporte público - Dia Hábil')
mask = (viajes_habiles.publico_privado=='Público') & (viajes_habiles.NombreActividadDestino=='Trabajo')
df = viajes_habiles[mask].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_mean(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración promedio (en minutos) de viaje en hora punta en transporte público - Dia Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración promedio (en minutos) de viaje al trabajo en transporte público - Dia Hábil

# %%
print('Duración mediana (en minutos) de viaje al trabajo en transporte público - Dia Hábil')
mask = (viajes_habiles.publico_privado=='Público') & (viajes_habiles.NombreActividadDestino=='Trabajo')
df = viajes_habiles[mask].groupby(["Quintil", 'MEDIOTRANSPORTE']).apply(lambda x: weighted_median(x, 'TiempoTotal', 'Ponderacion_x')).unstack()
fig, ax = plt.subplots(figsize=(7, 5))

ax = sns.heatmap(df, annot=True)

ax.set_title("Duración mediana (en minutos) de viaje en hora punta en transporte público - Dia Hábil")
ax.set_xlabel("Modo de Transporte")
ax.set_ylabel("Quintil")

fig.tight_layout()
# Out:
# Duración mediana (en minutos) de viaje al trabajo en transporte público - Dia Hábil
